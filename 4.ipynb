# %% [markdown]
# ### Working with JSON and SQL :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### importing the dataset

# %%
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR").head()
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# INR  https://www.exchangerate-api.com/terms  INR 2026-03-20
# AED  https://www.exchangerate-api.com/terms  INR 2026-03-20
# AFN  https://www.exchangerate-api.com/terms  INR 2026-03-20
# ALL  https://www.exchangerate-api.com/terms  INR 2026-03-20
# AMD  https://www.exchangerate-api.com/terms  INR 2026-03-20
#
#      time_last_updated   rates
# INR         1773964801  1.0000
# ...

# %% [markdown]
# ### Working with SQL
#  mysql.connect library for connecting to a MySQL database and executing SQL queries. It allows you to interact with the database, retrieve data, and perform various operations using SQL commands.

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      - -------------------------------------- 0.5/11.9 MB 1.1 MB/s eta 0:00:11
#      -- ------------------------------------- 0.8/11.9 MB 1.2 MB/s eta 0:00:10
#      --- ------------------------------------ 1.0/11.9 MB 1.2 MB/s eta 0:00:09
#      ----- ---------------------------------- 1.6/11.9 MB 1.4 MB/s eta 0:00:08
#      ------ --------------------------------- 1.8/11.9 MB 1.4 MB/s eta 0:00:08
#      ------- -------------------------------- 2.4/11.9 MB 1.6 MB/s eta 0:00:07
#      -------- ------------------------------- 2.6/11.9 MB 1.5 MB/s eta 0:00:07
#      ---------- ----------------------------- 3.1/11.9 MB 1.6 MB/s eta 0:00:06
#      ------------ --------------------------- 3.7/11.9 MB 1.7 MB/s eta 0:00:05
# ...

# %%
conn=mysql.connector.connect(
    host="localhost",
    user="your_username",
    password="your_password",
    database="your_database"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 conn=mysql.connector.connect(
#       2     host="localhost",
#       3     user="your_username",
#       4     password="your_password",
#       5     database="your_database"
#       6 )
#
# NameError: name 'mysql' is not defined

# %%
pd.read_sql_query("SELECT * FROM your_table", conn)
