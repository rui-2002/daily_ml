# %% [markdown]
# ## Pandas Profiling

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset/train.csv")
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 517          518         0       3                        Ryan, Mr. Patrick
# 720          721         1       2        Harper, Miss. Annie Jessie "Nina"
# 738          739         0       3                       Ivanoff, Mr. Kanio
# 830          831         1       3  Yasbeck, Mrs. Antoni (Selini Alexander)
# 231          232         0       3                 Larsson, Mr. Bengt Edvin
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 517    male   NaN      0      0  371110  24.1500   NaN        Q
# 720  female   6.0      0      1  248727  33.0000   NaN        S
# 738    male   NaN      0      0  349201   7.8958   NaN        S
# 830  female  15.0      1      0    2659  14.4542   NaN        C
# 231    male  29.0      0      0  347067   7.7750   NaN        S

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file="output.html")
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 97.04it/s]0<00:00, 29.62it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:04<00:00, 11.30it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:04<00:00,  4.90s/it]
# Render HTML: 100%|██████████| 1/1 [00:02<00:00,  2.98s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 78.32it/s]
