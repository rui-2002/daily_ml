# %% [markdown]
# ## Fetching from API

# %%
import pandas as pd
import requests

# %%
req = requests.get("https://api.exchangerate-api.com/v4/latest/INR")
req
# Out:
# <Response [200]>

# %%
req.json()
# Out:
# {'provider': 'https://www.exchangerate-api.com',
#  'WARNING_UPGRADE_TO_V6': 'https://www.exchangerate-api.com/docs/free',
#  'terms': 'https://www.exchangerate-api.com/terms',
#  'base': 'INR',
#  'date': '2026-03-21',
#  'time_last_updated': 1774051201,
#  'rates': {'INR': 1,
#   'AED': 0.0392,
#   'AFN': 0.688,
#   'ALL': 0.898,
#   'AMD': 4.04,
#   'ANG': 0.0191,
#   'AOA': 10.13,
#   'ARS': 15.5,
#   'AUD': 0.0151,
#   'AWG': 0.0191,
#   'AZN': 0.0182,
#   'BAM': 0.0181,
#   'BBD': 0.0214,
#   'BDT': 1.32,
#   'BGN': 0.0181,
#   'BHD': 0.00401,
#   'BIF': 32.2,
#   'BMD': 0.0107,
#   'BND': 0.0137,
#   'BOB': 0.0746,
#   'BRL': 0.0562,
#   'BSD': 0.0107,
#   'BTN': 1,
#   'BWP': 0.151,
#   'BYN': 0.0324,
#   'BZD': 0.0214,
#   'CAD': 0.0147,
#   'CDF': 24.94,
#   'CHF': 0.00843,
#   'CLF': 0.000247,
#   'CLP': 9.76,
#   'CNH': 0.0738,
#   'CNY': 0.0742,
#   'COP': 39.79,
#   'CRC': 5.04,
#   'CUP': 0.256,
#   'CVE': 1.02,
#   'CZK': 0.227,
#   'DJF': 1.9,
#   'DKK': 0.0692,
# ...

# %% [markdown]
# #### To convert json into dataframe

# %%
pd.DataFrame(req.json()).head()
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
#
#                                       terms base        date  \
# INR  https://www.exchangerate-api.com/terms  INR  2026-03-21
# AED  https://www.exchangerate-api.com/terms  INR  2026-03-21
# AFN  https://www.exchangerate-api.com/terms  INR  2026-03-21
# ALL  https://www.exchangerate-api.com/terms  INR  2026-03-21
# AMD  https://www.exchangerate-api.com/terms  INR  2026-03-21
#
#      time_last_updated   rates
# INR         1774051201  1.0000
# ...

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(5):
    req = requests.get("https://api.exchangerate-api.com/v4/latest/INR")
    df=df.append(pd.DataFrame(req.json()),ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24104\1977090502.py in ?()
#       1 for i in range(5):
#       2     req = requests.get("https://api.exchangerate-api.com/v4/latest/INR")
# ----> 3     df=df.append(pd.DataFrame(req.json()),ignore_index=True)
#
# c:\Users\sangw\miniconda3\envs\.venv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df.shape
# Out:
# (0, 0)
